# %%
import requests
from requests.exceptions import HTTPError,ConnectionError,Timeout
#下載
try:
   url = 'https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/O-A0091-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
   response = requests.get(url)
   response.raise_for_status()
   content = response.text
   print(content)
except ConnectionError:
    print("連線伺服器發生錯誤")
except Timeout:
    print("伺服器太忙,沒有回應")
except  HTTPError:
    print("伺服器回應連線錯誤")
except Exception:
    print("不知名的錯誤")
else:
    file = open('台灣日射量2.json',encoding='utf-8',mode='w',newline='')
    file.write(content)
    file.close()
# Out:
# {
#  "cwaopendata": {
#   "@xmlns": "urn:cwa:gov:tw:cwacommon:0.1",
#   "identifier": "45cf862a-920d-4f14-89cd-fb9c5493f99e",
#   "sender": "od@cwa.gov.tw",
#   "sent": "2024-08-28T19:09:20+08:00",
#   "status": "Actual",
#   "msgType": "Issue",
#   "dataid": "O-A0091-001",
#   "scope": "Public",
#   "dataset": {
#    "Station": [
#     {
#      "StationName": "基隆",
#      "StationId": "466940",
#      "ObsTime": {
#       "DateTime": "2024-08-28T19:00:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.135130",
#         "StationLongitude": "121.732265"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.133314",
#         "StationLongitude": "121.740475"
#        }
#       ],
#       "StationAltitude": "26.7"
#      },
#      "WeatherElement": {
# ...

# %%
import requests
from requests.exceptions import HTTPError,ConnectionError,Timeout
#下載
try:
   url = 'https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/O-A0091-001?Authorization=rdec-key-123-45678-011121314&format=JSON'
   response = requests.get(url)
   response.raise_for_status()
   content = response.text
   print(content)
except ConnectionError:
    print("連線伺服器發生錯誤")
except Timeout:
    print("伺服器太忙,沒有回應")
except  HTTPError:
    print("伺服器回應連線錯誤")
except Exception:
    print("不知名的錯誤")
else:
    with open("台灣日射量3.json",encoding="utf-8",mode="w",newline="") as file:
        file.write(content)
    print("存檔完成")
# Out:
# {
#  "cwaopendata": {
#   "@xmlns": "urn:cwa:gov:tw:cwacommon:0.1",
#   "identifier": "3de9673e-0e4f-4f1e-aa0b-d7bb1330afa1",
#   "sender": "od@cwa.gov.tw",
#   "sent": "2024-08-28T19:22:20+08:00",
#   "status": "Actual",
#   "msgType": "Issue",
#   "dataid": "O-A0091-001",
#   "scope": "Public",
#   "dataset": {
#    "Station": [
#     {
#      "StationName": "基隆",
#      "StationId": "466940",
#      "ObsTime": {
#       "DateTime": "2024-08-28T19:10:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.135130",
#         "StationLongitude": "121.732265"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.133314",
#         "StationLongitude": "121.740475"
#        }
#       ],
#       "StationAltitude": "26.7"
#      },
#      "WeatherElement": {
# ...

# %%
with open('台灣日射量.json',encoding='utf-8') as file:
    content = file.read()
    print(type(content))
    print(content)
# Out:
# <class 'str'>
# {
#  "cwaopendata": {
#   "@xmlns": "urn:cwa:gov:tw:cwacommon:0.1",
#   "identifier": "235dd74e-4404-4e57-b920-7f432ec4c316",
#   "sender": "od@cwa.gov.tw",
#   "sent": "2024-08-27T18:12:20+08:00",
#   "status": "Actual",
#   "msgType": "Issue",
#   "dataid": "O-A0091-001",
#   "scope": "Public",
#   "dataset": {
#    "Station": [
#     {
#      "StationName": "基隆",
#      "StationId": "466940",
#      "ObsTime": {
#       "DateTime": "2024-08-27T18:00:00+08:00"
#      },
#      "GeoInfo": {
#       "Coordinates": [
#        {
#         "CoordinateName": "TWD67",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.135130",
#         "StationLongitude": "121.732265"
#        },
#        {
#         "CoordinateName": "WGS84",
#         "CoordinateFormat": "decimal degrees",
#         "StationLatitude": "25.133314",
#         "StationLongitude": "121.740475"
#        }
#       ],
#       "StationAltitude": "26.7"
#      },
# ...

# %%
empty:list = []
empty
# Out:
# []

# %%
weeksdays:list[str] = ['星期一', '星期二', '星期三', '星期四', '星期五', '星期六', '星期日']
weeksdays
# Out:
# ['星期一', '星期二', '星期三', '星期四', '星期五', '星期六', '星期日']

# %%
print(weeksdays[0])
print(weeksdays[6])
weeksdays[6] = 'sun'
print(weeksdays[6])
# Out:
# 星期一
# sunday
# sun

# %%
print(weeksdays[1])
print(weeksdays[4])
weeksdays[4] = 'fri'
print(weeksdays[4])
# Out:
# 星期二
# fri
# fri

# %%
for i in weeksdays:
    print(i)
# Out:
# 星期一
# 星期二
# 星期三
# 星期四
# fri
# 星期六
# sun

# %%
students = {'Billy':60,'Kooda':78,'Simon':46}

students
# Out:
# {'Billy': 60, 'Kooda': 78, 'Simon': 46}

# %%
print(students['Billy'])
# Out:
# 60

# %%
for key in students:
    print(key)
# Out:
# Billy
# Kooda
# Simon

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][2]
# Out:
# 3

# %%
print(matrix[0][2])
# Out:
# 3

# %%
people = [
    {'name':'Billy','age':60,},
    {'name':'Kooda','age':78},
    {'name':'Simon','age':46}
]

people
# Out:
# [{'name': 'Billy', 'age': 60},
#  {'name': 'Kooda', 'age': 78},
#  {'name': 'Simon', 'age': 46}]

# %%
print(people[0])

print(people[0]['name'])
# Out:
# {'name': 'Billy', 'age': 60}
# Billy

# %%
student_scores = {
    'Billy':{'Math':87,'Science' : 95},
    'Kooda':{'Math':36,'Science' : 55},
    'Ishle':{'Math':69,'Science' : 88}


}

student_scores['Billy']['Math']
# Out:
# 87

# %%
employee = {
    'HR':['Alice', 'Bob'],
    'IT':['Charlie', 'David'],
    'Finance':['Eve', 'Frank']
}

employee['IT'][1]
# Out:
# 'David'

# %%
with open('abc.csv',encoding='utf-8',newline='')as file:
    content = file.read()
    print(str)
# Out:
# <class 'str'>

# %%
import csv
with open('abc.csv',encoding='utf-8',newline='')as file:

    reader = csv.reader(file)
    content:list = list(reader)

    print(content)
# Out:
# [['證券代號', '證券名稱', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數'], ['0050', '元大台灣50', '46,790,503', '3,463,425,684', '74.95', '75.25', '72.80', '72.80', '-2.05', '23,021'], ['0051', '元大中型100', '43,172', '1,177,199', '27.30', '27.57', '26.75', '26.75', '-0.52', '45'], ['0052', '富邦科技', '161,425', '9,156,750', '57.60', '57.60', '55.35', '55.35', '-2.35', '67'], ['0053', '元大電子', '35,076', '1,163,448', '33.36', '33.61', '32.56', '32.69', '-0.67', '19'], ['0054', '元大台商50', '27,028', '507,569', '18.80', '19.00', '18.64', '18.64', '-0.36', '13'], ['0055', '元大MSCI金融', '62,050', '940,984', '15.35', '15.35', '15.00', '15.10', '-0.32', '52'], ['0056', '元大高股息', '80,530,934', '1,897,973,002', '23.70', '23.82', '23.26', '23.29', '-0.38', '35,938'], ['0057', '富邦摩台', '20,011', '967,537', '48.35', '48.35', '48.35', '48.35', '-0.90', '3'], ['0061', '元大寶滬深', '5,889,414', '103,296,868', '17.30', '18.50', '16.90', '17.93', '+1.00', '2,346'], ['006203', '元大MSCI台灣', '7,000', '242,470', '34.98', 
# ...

# %%
import csv
from pprint import pprint
with open('abc.csv',encoding='utf-8',newline='')as file:

    reader = csv.reader(file)
    content:list = list(reader)

    pprint(content)
# Out:
# [['證券代號', '證券名稱', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數'],
#  ['0050',
#   '元大台灣50',
#   '46,790,503',
#   '3,463,425,684',
#   '74.95',
#   '75.25',
#   '72.80',
#   '72.80',
#   '-2.05',
#   '23,021'],
#  ['0051',
#   '元大中型100',
#   '43,172',
#   '1,177,199',
#   '27.30',
#   '27.57',
#   '26.75',
#   '26.75',
#   '-0.52',
#   '45'],
#  ['0052',
#   '富邦科技',
#   '161,425',
#   '9,156,750',
#   '57.60',
#   '57.60',
#   '55.35',
#   '55.35',
#   '-2.35',
#   '67'],
#  ['0053',
#   '元大電子',
#   '35,076',
#   '1,163,448',
#   '33.36',
#   '33.61',
#   '32.56',
#   '32.69',
#   '-0.67',
#   '19'],
#  ['0054',
#   '元大台商50',
#   '27,028',
#   '507,569',
#   '18.80',
#   '19.00',
#   '18.64',
#   '18.64',
#   '-0.36',
#   '13'],
#  ['0055',
#   '元大MSCI金融',
#   '62,050',
#   '940,984',
#   '15.35',
#   '15.35',
#   '15.00',
#   '15.10',
#   '-0.32',
#   '52'],
#  ['0056',
#   '元大高股息',
#   '80,530,934',
#   '1,897,973,002',
#   '23.70',
#   '23.82',
#   '23.26',
# ...

# %%
import csv
from pprint import pprint
with open('abc.csv',encoding='utf-8',newline='')as file:

    dicReader = csv.DictReader(file)
    content:list = list(dicReader)

    pprint(content)
# Out:
# [{'成交筆數': '23,021',
#   '成交股數': '46,790,503',
#   '成交金額': '3,463,425,684',
#   '收盤價': '72.80',
#   '最低價': '72.80',
#   '最高價': '75.25',
#   '漲跌價差': '-2.05',
#   '證券代號': '0050',
#   '證券名稱': '元大台灣50',
#   '開盤價': '74.95'},
#  {'成交筆數': '45',
#   '成交股數': '43,172',
#   '成交金額': '1,177,199',
#   '收盤價': '26.75',
#   '最低價': '26.75',
#   '最高價': '27.57',
#   '漲跌價差': '-0.52',
#   '證券代號': '0051',
#   '證券名稱': '元大中型100',
#   '開盤價': '27.30'},
#  {'成交筆數': '67',
#   '成交股數': '161,425',
#   '成交金額': '9,156,750',
#   '收盤價': '55.35',
#   '最低價': '55.35',
#   '最高價': '57.60',
#   '漲跌價差': '-2.35',
#   '證券代號': '0052',
#   '證券名稱': '富邦科技',
#   '開盤價': '57.60'},
#  {'成交筆數': '19',
#   '成交股數': '35,076',
#   '成交金額': '1,163,448',
#   '收盤價': '32.69',
#   '最低價': '32.56',
#   '最高價': '33.61',
#   '漲跌價差': '-0.67',
#   '證券代號': '0053',
#   '證券名稱': '元大電子',
#   '開盤價': '33.36'},
#  {'成交筆數': '13',
#   '成交股數': '27,028',
#   '成交金額': '507,569',
#   '收盤價': '18.64',
#   '最低價': '18.64',
#   '最高價': '19.00',
#   '漲跌價差': '-0.36',
# ...

# %%
for item in content:
     print(item)
# Out:
# {'證券代號': '0050', '證券名稱': '元大台灣50', '成交股數': '46,790,503', '成交金額': '3,463,425,684', '開盤價': '74.95', '最高價': '75.25', '最低價': '72.80', '收盤價': '72.80', '漲跌價差': '-2.05', '成交筆數': '23,021'}
# {'證券代號': '0051', '證券名稱': '元大中型100', '成交股數': '43,172', '成交金額': '1,177,199', '開盤價': '27.30', '最高價': '27.57', '最低價': '26.75', '收盤價': '26.75', '漲跌價差': '-0.52', '成交筆數': '45'}
# {'證券代號': '0052', '證券名稱': '富邦科技', '成交股數': '161,425', '成交金額': '9,156,750', '開盤價': '57.60', '最高價': '57.60', '最低價': '55.35', '收盤價': '55.35', '漲跌價差': '-2.35', '成交筆數': '67'}
# {'證券代號': '0053', '證券名稱': '元大電子', '成交股數': '35,076', '成交金額': '1,163,448', '開盤價': '33.36', '最高價': '33.61', '最低價': '32.56', '收盤價': '32.69', '漲跌價差': '-0.67', '成交筆數': '19'}
# {'證券代號': '0054', '證券名稱': '元大台商50', '成交股數': '27,028', '成交金額': '507,569', '開盤價': '18.80', '最高價': '19.00', '最低價': '18.64', '收盤價': '18.64', '漲跌價差': '-0.36', '成交筆數': '13'}
# ...

# %%
'元大' in '元大電子'
# Out:
# True

# %%
for item in content:
     if '元大' in item['證券名稱']:
         print(item)
# Out:
# {'證券代號': '0050', '證券名稱': '元大台灣50', '成交股數': '46,790,503', '成交金額': '3,463,425,684', '開盤價': '74.95', '最高價': '75.25', '最低價': '72.80', '收盤價': '72.80', '漲跌價差': '-2.05', '成交筆數': '23,021'}
# {'證券代號': '0051', '證券名稱': '元大中型100', '成交股數': '43,172', '成交金額': '1,177,199', '開盤價': '27.30', '最高價': '27.57', '最低價': '26.75', '收盤價': '26.75', '漲跌價差': '-0.52', '成交筆數': '45'}
# {'證券代號': '0053', '證券名稱': '元大電子', '成交股數': '35,076', '成交金額': '1,163,448', '開盤價': '33.36', '最高價': '33.61', '最低價': '32.56', '收盤價': '32.69', '漲跌價差': '-0.67', '成交筆數': '19'}
# {'證券代號': '0054', '證券名稱': '元大台商50', '成交股數': '27,028', '成交金額': '507,569', '開盤價': '18.80', '最高價': '19.00', '最低價': '18.64', '收盤價': '18.64', '漲跌價差': '-0.36', '成交筆數': '13'}
# {'證券代號': '0055', '證券名稱': '元大MSCI金融', '成交股數': '62,050', '成交金額': '940,984', '開盤價': '15.35', '最高價': '15.35', '最低價': '15.00', '收盤價': '15.10', '漲跌價差': '-0.32', '成交筆數': '52'}
# ...

# %%
searchs:list = []
for item in content:
     if '元大' in item['證券名稱']:
         searchs.append(item)

pprint(searchs)
# Out:
# [{'成交筆數': '23,021',
#   '成交股數': '46,790,503',
#   '成交金額': '3,463,425,684',
#   '收盤價': '72.80',
#   '最低價': '72.80',
#   '最高價': '75.25',
#   '漲跌價差': '-2.05',
#   '證券代號': '0050',
#   '證券名稱': '元大台灣50',
#   '開盤價': '74.95'},
#  {'成交筆數': '45',
#   '成交股數': '43,172',
#   '成交金額': '1,177,199',
#   '收盤價': '26.75',
#   '最低價': '26.75',
#   '最高價': '27.57',
#   '漲跌價差': '-0.52',
#   '證券代號': '0051',
#   '證券名稱': '元大中型100',
#   '開盤價': '27.30'},
#  {'成交筆數': '19',
#   '成交股數': '35,076',
#   '成交金額': '1,163,448',
#   '收盤價': '32.69',
#   '最低價': '32.56',
#   '最高價': '33.61',
#   '漲跌價差': '-0.67',
#   '證券代號': '0053',
#   '證券名稱': '元大電子',
#   '開盤價': '33.36'},
#  {'成交筆數': '13',
#   '成交股數': '27,028',
#   '成交金額': '507,569',
#   '收盤價': '18.64',
#   '最低價': '18.64',
#   '最高價': '19.00',
#   '漲跌價差': '-0.36',
#   '證券代號': '0054',
#   '證券名稱': '元大台商50',
#   '開盤價': '18.80'},
#  {'成交筆數': '52',
#   '成交股數': '62,050',
#   '成交金額': '940,984',
#   '收盤價': '15.10',
#   '最低價': '15.00',
#   '最高價': '15.35',
#   '漲跌價差': '-0.32',
# ...

# %%
searchs:list = []
for item in content:
     if '元大' in item['證券名稱']:
         searchs.append(item)

list(searchs[0].keys())
# Out:
# ['證券代號', '證券名稱', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數']

# %%
searchs:list = []
for item in content:
     if '元大' in item['證券名稱']:
         searchs.append(item)

keys:list[str] = list(searchs[0].keys())
keys
# Out:
# ['證券代號', '證券名稱', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數']

# %%
with open('search.csv',mode='w',encoding='utf-8',newline='') as file:
    dictWriter = csv.DictWriter(file,keys)
    dictWriter.writeheader()
    dictWriter.writerows(searchs)

# %%
import csv
from pprint import pprint
with open("歷年國內主要觀光遊憩據點遊客人數月別統計.csv",encoding="utf-8",newline="") as file:
    dictReader = csv.DictReader(file)
    contents:list = list(dictReader)
pprint(contents) 
searchs1:list = []
forInItem = {'觀光遊憩區': '玉山國家公園', '縣市別': '南投縣'}

# Loop to forInItem
for key in forInItem:
    # Find list of dictionary
    searchs:list = []
    for item in contents:
        if forInItem[key] in item[key]:
            searchs.append(item)

    # Find keys of the dictionary
    keys:list[str] = list(searchs[0].keys())

    # Save the .csv file
    with open(f'{forInItem[key]}.csv',mode='w',encoding='utf-8',newline='') as file:
        dictWriter = csv.DictWriter(file, keys)
        dictWriter.writeheader()
        dictWriter.writerows(searchs)
# Out:
# [{'10月': '11515',
#   '11月': '6896',
#   '12月': '9631',
#   '1月': '12187',
#   '2月': '18612',
#   '3月': '18580',
#   '4月': '13329',
#   '5月': '14179',
#   '6月': '11397',
#   '7月': '16000',
#   '8月': '11791',
#   '9月': '10469',
#   '合計': '154586',
#   '細分': '陽明山遊客中心',
#   '縣市別': '臺北市',
#   '觀光遊憩區': '陽明山國家公園',
#   '類型': '國家公園',
#   '\ufeff年別': '2012'},
#  {'10月': '3701',
#   '11月': '2863',
#   '12月': '2983',
#   '1月': '2597',
#   '2月': '3617',
#   '3月': '5221',
#   '4月': '4317',
#   '5月': '3497',
#   '6月': '2815',
#   '7月': '3005',
#   '8月': '2497',
#   '9月': '2764',
#   '合計': '39877',
#   '細分': '陽明書屋',
#   '縣市別': '臺北市',
#   '觀光遊憩區': '陽明山國家公園',
#   '類型': '國家公園',
#   '\ufeff年別': '2012'},
#  {'10月': '36000',
#   '11月': '35000',
#   '12月': '33000',
#   '1月': '161000',
#   '2月': '463000',
#   '3月': '705200',
#   '4月': '85600',
#   '5月': '38600',
#   '6月': '28000',
#   '7月': '51700',
#   '8月': '44700',
#   '9月': '39000',
#   '合計': '1720800',
#   '細分': '陽明公園',
#   '縣市別': '臺北市',
# ...
