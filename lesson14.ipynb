# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
colors =['yellow', 'green', 'red', 'blue']
explode = [0.2, 0, 0, 0]
#figure = plt.figure()
#axes = figure.add_subplot()
figure, axes = plt.subplots()
axes.pie(values,labels=labels,colors=colors,startangle=180,explode=explode,shadow=True,autopct='%.1f%%')
plt.show()

# %%
(5,7)
# Out:
# (5, 7)

# %%
(5,)
# Out:
# (5,)

# %%
list_a = [1,3,5,7,9]
list_b = [0,2,4,6,8]
list_a + list_b
# Out:
# [1, 3, 5, 7, 9, 0, 2, 4, 6, 8]

# %%
import numpy as np
array_a = np.array([1,3,5,7,9])
array_b = np.array([0,2,4,6,8])
type(array_a)
array_a + array_b
# Out:
# array([ 1,  5,  9, 13, 17])

# %%
import numpy as np

l = [[1,2,3],[2,3,4]]
array = np.array(l)
array.ndim,array.shape,array.size,array.dtype
# Out:
# (2, (2, 3), 6, dtype('int64'))

# %%
import numpy as np
np.random.randn(10,5)
# Out:
# array([[-0.68313124,  1.08868743,  1.23412793,  0.27369517, -0.7231233 ],
#        [-0.57202759, -0.4600648 , -0.12255737,  1.29263464, -0.35408256],
#        [ 0.7907229 , -0.2810229 ,  0.41213765, -1.36154184,  0.40659515],
#        [-0.23709784,  0.96123231,  2.26410804, -2.26917322,  0.84817716],
#        [-0.68790479, -0.86489501,  1.04697735,  1.36650442, -0.36829384],
#        [ 0.14366776,  1.8660004 ,  1.57208845, -0.45081953,  0.2435707 ],
#        [ 0.08302609,  0.10569737, -0.72773865, -1.33517512,  0.19638069],
#        [-1.36540433, -0.60980873, -0.51719453,  1.170978  ,  1.28712749],
#        [ 0.93334595,  0.09287435, -2.43893469,  0.08086415,  0.28036357],
#        [-1.02706629, -1.25818815, -2.48303731,  0.90364232, -0.86697108]])

# %%
import numpy as np
m = int(input("enter number of m"))
n = int(input("enter number of n"))
o = int(input("enter number of o"))
scores = np.random.randint(m,n,size = (m,o))

scores
# Out:
# array([[69, 65, 61, 71, 70],
#        [67, 54, 88, 60, 95],
#        [85, 90, 61, 73, 90],
#        [50, 54, 60, 64, 88],
#        [60, 55, 92, 70, 58],
#        [90, 99, 87, 65, 91],
#        [57, 50, 61, 92, 68],
#        [77, 73, 64, 79, 94],
#        [90, 86, 73, 97, 74],
#        [75, 99, 74, 96, 61],
#        [69, 84, 88, 76, 67],
#        [63, 55, 98, 61, 67],
#        [66, 74, 64, 58, 50],
#        [62, 74, 56, 66, 74],
#        [58, 83, 78, 73, 75],
#        [96, 92, 74, 82, 92],
#        [64, 74, 83, 58, 97],
#        [61, 72, 78, 93, 57],
#        [87, 64, 59, 82, 90],
#        [78, 87, 67, 71, 65],
#        [54, 50, 83, 67, 88],
#        [78, 86, 69, 50, 69],
#        [97, 59, 54, 84, 84],
#        [80, 52, 63, 80, 96],
#        [93, 63, 79, 65, 55],
#        [81, 83, 85, 95, 68],
#        [92, 63, 62, 63, 91],
#        [51, 98, 64, 87, 72],
#        [98, 87, 61, 78, 93],
#        [61, 99, 62, 53, 59],
#        [52, 91, 66, 61, 95],
#        [77, 77, 82, 52, 77],
#        [63, 69, 86, 53, 55],
#        [69, 77, 55, 89, 65],
#        [72, 76, 61, 65, 76],
#        [89, 66, 88, 66, 89],
#        [84, 74, 56, 81, 84],
#        [83, 92, 71, 52, 58],
#        [90, 50, 89, 95, 78],
#        [89, 90, 99, 61, 72],
#        [67, 50, 73, 74, 80],
#        [77, 60, 55, 59, 98],
#        [93, 69, 93, 97, 88],
#        [54, 65, 94, 88, 87],
#        [77, 71, 59, 87, 90],
#        [74, 84, 62, 57, 98],
#        [88, 69, 51, 51, 72],
#        [93, 87, 52, 75, 65],
#        [76, 72, 51, 59, 81],
#        [66, 85, 93, 63, 99]])

# %%
scores[0,:]

scores[:5,:]

scores[-5:,:]
# Out:
# array([[74, 84, 62, 57, 98],
#        [88, 69, 51, 51, 72],
#        [93, 87, 52, 75, 65],
#        [76, 72, 51, 59, 81],
#        [66, 85, 93, 63, 99]])

# %%
scores[:,0]
# Out:
# array([69, 67, 85, 50, 60, 90, 57, 77, 90, 75, 69, 63, 66, 62, 58, 96, 64,
#        61, 87, 78, 54, 78, 97, 80, 93, 81, 92, 51, 98, 61, 52, 77, 63, 69,
#        72, 89, 84, 83, 90, 89, 67, 77, 93, 54, 77, 74, 88, 93, 76, 66])

# %%
scores[:,1]
# Out:
# array([65, 54, 90, 54, 55, 99, 50, 73, 86, 99, 84, 55, 74, 74, 83, 92, 74,
#        72, 64, 87, 50, 86, 59, 52, 63, 83, 63, 98, 87, 99, 91, 77, 69, 77,
#        76, 66, 74, 92, 50, 90, 50, 60, 69, 65, 71, 84, 69, 87, 72, 85])

# %%
n = int(input("enter number of n"))
total = 0
for i in range(0,n):
    total += scores[:,i]

total
# Out:
# array([336, 364, 399, 316, 335, 432, 328, 387, 420, 405, 384, 344, 312,
#        332, 367, 436, 376, 361, 382, 368, 342, 352, 378, 371, 355, 412,
#        371, 372, 417, 334, 365, 365, 326, 355, 350, 398, 379, 356, 402,
#        411, 344, 349, 440, 388, 384, 375, 331, 372, 339, 406])

# %%
np.sum(scores,axis=1)
# Out:
# array([336, 364, 399, 316, 335, 432, 328, 387, 420, 405, 384, 344, 312,
#        332, 367, 436, 376, 361, 382, 368, 342, 352, 378, 371, 355, 412,
#        371, 372, 417, 334, 365, 365, 326, 355, 350, 398, 379, 356, 402,
#        411, 344, 349, 440, 388, 384, 375, 331, 372, 339, 406])

# %%
np.mean(scores,axis=1)
# Out:
# array([67.2, 72.8, 79.8, 63.2, 67. , 86.4, 65.6, 77.4, 84. , 81. , 76.8,
#        68.8, 62.4, 66.4, 73.4, 87.2, 75.2, 72.2, 76.4, 73.6, 68.4, 70.4,
#        75.6, 74.2, 71. , 82.4, 74.2, 74.4, 83.4, 66.8, 73. , 73. , 65.2,
#        71. , 70. , 79.6, 75.8, 71.2, 80.4, 82.2, 68.8, 69.8, 88. , 77.6,
#        76.8, 75. , 66.2, 74.4, 67.8, 81.2])

# %%
import numpy as np
n = int(input("enter number of n"))
t = np.arange(0,n,0.1)
t.size
# Out:
# 50

# %%
import numpy as np
import matplotlib.pyplot as plt
n = int(input("enter number of n"))
t = np.arange(0,n,0.1)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)

y2
# Out:
# array([ 1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699,
#         1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699,
#         1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699,
#         1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699,
#         1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699])

# %%
import numpy as np
import matplotlib.pyplot as plt
n = int(input("enter number of n"))
t = np.arange(0,n,0.1)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)

figure= plt.figure(figsize=(8,15))
axes1 = figure.add_subplot(2,1,1)
axes2 = figure.add_subplot(2,1,2)

axes1.plot(t,y1,'b-.')
axes2.plot(t,y2,'r-.')
plt.show()

# %%
index = ['apple','banana','orange','tomato','guava']
values = np.array([5,7,3,4,6])*1000
figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)

axes.bar(index, values)
plt.show()

# %%
import numpy as np
import pandas as pd

m = int(input("enter number of m"))
n = int(input("enter number of n"))
o = int(input("enter number of o"))

scores = np.random.randint(m,n,size = (m,o))

df1 = pd.DataFrame(scores,columns=['國文', '英文', '數學', '歷史', '探索'])
df1
# Out:
#      國文   英文  數學   歷史   探索
# 0    87   71  61   86   67
# 1   100   68  80   62   78
# 2    89   69  68   79   93
# 3    70   57  76   50   54
# 4    64   82  69   97  100
# 5    92   80  84   66   53
# 6    93   61  54   68   77
# 7    66   97  58   54   85
# 8    80   60  58   62   99
# 9    88   61  99   51   66
# 10   90   51  90   91  100
# 11   94   97  91   61   81
# 12   56   69  72   86  100
# 13   73   89  64   99   80
# 14   64   81  73   70   81
# 15   88   52  57   74   96
# 16   71   81  59   78   94
# 17   92   51  88   98   61
# 18   50   75  65   63   86
# 19   87   77  99   72   61
# 20   97   56  61   80   82
# 21   66   79  98   92   74
# 22   84   50  53   75   60
# 23   51   83  51  100   60
# 24   63   94  84   93   93
# 25   71   96  95   88   52
# 26   96   64  52   57   89
# 27   86   93  73   92   54
# 28   65   63  57   51   80
# 29   86   52  71   94   72
# 30   86   64  93   84   54
# 31   55   86  90   97   89
# 32   81   72  54   80   67
# 33   82   81  80   99   52
# 34   59   55  77   96   68
# 35   73   85  53   65  100
# 36   68   50  81   75   74
# 37   77   57  90  100   90
# 38   56   72  93   50   76
# 39   68   58  86   73   50
# 40   72   84  55   79   98
# 41   74   91  55   67   91
# 42   87   92  91   53   86
# 43   59   64  58   74   94
# 44   54   68  95   72   51
# 45   86   79  84   96   52
# 46   66  100  81   87   72
# 47   90   56  59   81   73
# 48   99   90  81   97   67
# 49   85   93  68   90   72

# %%
import random
with open('names.txt',encoding='utf-8') as file:
# 蔡明平   88  67   89   77   54
# 張牧聿   79  57   74   95   87
# 張天亨   95  61   69   90   72
# 林群清   57  70   51   50   64
# 李蓉瑞   58  86   61   84   94
# 楊偉翔   93  63   64   58   75
# 楊健麟   99  74   54   72   69
# 金宜芳   84  79   56   94   66
# 錢欣潔   51  83   97   71   70
# 王坤安   50  62   70   52   88
# 陳志偉   83  71   73   64   57
# 陳倩妮   76  67   90   56   82
# 蔡世馨   77  81  100   72   92
# 高士凱   75  87   52   86   59
# 王良斌   69  98   87   93   97
# 蔡偉成   54  79   61   60   63
# 朱彥志   51  53   53   88   86
# 趙偉銘   89  76   89   76   56

# %%
df1.to_numpy()
# Out:
# array([[ 55,  92,  72,  78,  98],
#        [ 52,  64,  98,  82,  68],
#        [ 79,  74,  59,  86,  93],
#        [ 86,  91,  61,  75,  82],
#        [ 79,  72,  68,  89,  83],
#        [ 72,  64,  84, 100,  76],
#        [ 85,  72,  94,  94,  71],
#        [ 59,  96,  84,  52,  59],
#        [ 58,  88,  71,  55,  74],
#        [ 74,  99,  72,  63,  62],
#        [ 98,  81,  97,  79,  85],
#        [ 57,  50,  56,  87,  54],
#        [ 53,  51,  83,  81,  96],
#        [ 77,  92,  64,  75,  69],
#        [ 95,  94,  75,  50,  76],
#        [ 68,  74,  88, 100,  82],
#        [ 56,  64,  87,  90,  96],
#        [ 92,  75,  53,  65,  78],
#        [ 59,  78,  82,  75, 100],
#        [ 84,  66,  72,  71,  96],
#        [ 86,  87,  69,  59,  56],
#        [ 64,  74,  54,  62,  95],
#        [ 67,  69,  89,  63,  79],
#        [ 79,  61,  51,  85,  87],
#        [ 93,  60,  93,  97,  92],
#        [ 99,  91,  79,  89,  79],
#        [ 60,  85,  69,  74,  55],
#        [ 76,  58,  77,  68,  71],
#        [100,  94,  97,  97,  95],
#        [ 51,  83,  55,  69,  79],
#        [ 64,  65,  60,  58,  59],
#        [ 52,  86,  71,  78,  59],
#        [ 88,  67,  89,  77,  54],
#        [ 79,  57,  74,  95,  87],
#        [ 95,  61,  69,  90,  72],
#        [ 57,  70,  51,  50,  64],
#        [ 58,  86,  61,  84,  94],
#        [ 93,  63,  64,  58,  75],
#        [ 99,  74,  54,  72,  69],
#        [ 84,  79,  56,  94,  66],
#        [ 51,  83,  97,  71,  70],
#        [ 50,  62,  70,  52,  88],
#        [ 83,  71,  73,  64,  57],
#        [ 76,  67,  90,  56,  82],
#        [ 77,  81, 100,  72,  92],
#        [ 75,  87,  52,  86,  59],
#        [ 69,  98,  87,  93,  97],
#        [ 54,  79,  61,  60,  63],
#        [ 51,  53,  53,  88,  86],
#        [ 89,  76,  89,  76,  56]])

# %%
df1.to_csv('student.csv')

# %%
df1.to_excel('student.xlsx',sheet_name='3年5班')

# %%
import pandas as pd

df = pd.read_csv('student.csv',index_col=0)
df
# Out:
#       國文  英文   數學   地理   探索
# 黃嘉琪   55  92   72   78   98
# 郭淑真   64  65   60   58   59  306  61.2
# 林思賢   52  86   71   78   59  346  69.2
# 蔡明平   88  67   89   77   54  375  75.0
# 張牧聿   79  57   74   95   87  392  78.4
# 張天亨   95  61   69   90   72  387  77.4
# 林群清   57  70   51   50   64  292  58.4
# 李蓉瑞   58  86   61   84   94  383  76.6
# 楊偉翔   93  63   64   58   75  353  70.6
# 楊健麟   99  74   54   72   69  368  73.6
# 金宜芳   84  79   56   94   66  379  75.8
# 錢欣潔   51  83   97   71   70  372  74.4
# 王坤安   50  62   70   52   88  322  64.4
# 陳志偉   83  71   73   64   57  348  69.6
# 陳倩妮   76  67   90   56   82  371  74.2
# 蔡世馨   77  81  100   72   92  422  84.4
# 高士凱   75  87   52   86   59  359  71.8
# 王良斌   69  98   87   93   97  444  88.8
# 蔡偉成   54  79   61   60   63  317  63.4
# 朱彥志   51  53   53   88   86  331  66.2
# 趙偉銘   89  76   89   76   56  386  77.2

# %%
df.loc['王志謙']
# Out:
# 國文     85.0
# 英文     72.0
# 數學     94.0
# 地理     94.0
# 探索     71.0
# 總分    416.0
# 平均     83.2
# Name: 王志謙, dtype: float64

# %%
df.iloc[0,:]
# Out:
# 國文     55.0
# 英文     92.0
# 數學     72.0
# 地理     78.0
# 探索     98.0
# 總分    395.0
# 平均     79.0
# Name: 黃嘉琪, dtype: float64

# %%
df.iloc[:5,:]
# Out:
#      國文  英文  數學  地理  探索   總分    平均
# 黃嘉琪  55  92  72  78  98  395  79.0
# 黃名明  52  64  98  82  68  364  72.8
# 王人仰  79  74  59  86  93  391  78.2
# 唐翊修  86  91  61  75  82  395  79.0
# 謝佳穎  79  72  68  89  83  391  78.2

# %%
import requests
from requests import Response
from pydantic import BaseModel, RootModel, Field,field_validator, field_serializer
from datetime import datetime
import pandas as pd

youbike_url = 'https://data.ntpc.gov.tw/api/datasets/c51d5111-c300-44c9-b4f1-4b28b9929ca2/json?size=1000'
try:
    respons:Response = requests.request('GET',youbike_url)
    respons.raise_for_status()
except Exception:
    print("下載錯誤")
else:
    content = respons.text

class Factory(BaseModel):
    名稱: str = Field(alias='organizer')
    註冊號碼: str = Field(alias='no')
    地址: str = Field(alias='address')
    統編: str = Field(alias='tax_id_number')
    緯度: float|None = Field(alias='wgs84ax') 
    經度: float|None = Field(alias='wgs84ay') 
    日期: datetime = Field(alias='date')

    @field_validator('緯度', '經度', mode='before') 
    @classmethod
    def validate_coordinates(cls, value):
        if value == None:
            return None
        else:
            return round(float(value), ndigits=5)

    @field_serializer('日期')
    def date_serial(self, date: datetime) -> str:
        return date.strftime(f'中華民國{date.year-1911}年%m月%d日 %H:%M:%S')

class Companys(RootModel):
    root: list[Factory]

companys: Companys = Companys.model_validate_json(content)
companys_list = companys.model_dump()

df = pd.DataFrame(companys_list)

df.to_csv('factory.csv',index=False, encoding='utf-8')

df.to_excel('factory.xlsx',sheet_name='工廠名單')
